# %% [markdown]
# ## PARIS SUBSIDIES: DATA CLEANING (SIRENE)

# %% [markdown]
# ### LIBRAIRIES IMPORT

# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

# %%
from geopy.geocoders import Nominatim

# %% [markdown]
# ### DATA IMPORT

# %%
SIRENE = pd.read_csv('../00_DataFiles/01_Collected/ParisSubsidies_SIRENE.csv', dtype = str)
SIRENE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11161 entries, 0 to 11160
# Data columns (total 18 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   fields.libellecommuneetablissement         11160 non-null  object
#  1   fields.categorieentreprise                 6609 non-null   object
#  2   fields.etatadministratifunitelegale        11161 non-null  object
#  3   fields.geolocetablissement                 11021 non-null  object
#  4   fields.trancheeffectifsunitelegale         6850 non-null   object
#  5   fields.trancheeffectifsunitelegaletriable  6850 non-null   object
#  6   fields.siretsiegeunitelegale               11161 non-null  object
#  7   fields.siret                               11161 non-null  object
#  8   fields.etablissementsiege                  11161 non-null  object
#  9   fields.adresseetablissement                11155 non-null  object
#  10  fields.sectionunitelegale                  11161 non-null  object
#  11  fields.codepostaletablissement             11160 non-null  object
#  12  fields.caractereemployeurunitelegale       11161 non-null  object
#  13  fields.datecreationunitelegale             11161 non-null  object
#  14  fields.datecreationetablissement           11161 non-null  object
#  15  fields.denominationunitelegale             11157 non-null  object
#  16  geometry.type                              11021 non-null  object
#  17  geometry.coordinates                       11021 non-null  object
# dtypes: object(18)
# memory usage: 1.5+ MB

# %% [markdown]
# #### Profile report before cleaning

# %%
profile = ProfileReport(SIRENE.reset_index(drop=True), title='SIRENE Profiling Report - Before Cleaning', interactions={'continuous': False})
profile.to_file('ProfileReports/ParisSubsidies_SIRENE_bf.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### FIELD BY FIELD APPROACH

# %% [markdown]
# #### Duplicates

# %%
SIRENE.loc[SIRENE.duplicated(subset = SIRENE.drop(['geometry.coordinates', 'fields.geolocetablissement'], axis = 1).columns, keep = False)].sort_values(by='fields.siret')
# Out:
#       fields.libellecommuneetablissement fields.categorieentreprise  \
# 989                            MONTREUIL                        PME
# 11159                          MONTREUIL                        PME
# 11026                           PARIS 11                        PME
# 6978                            PARIS 11                        PME
# 11093                            PARIS 6                        PME
# ...                                  ...                        ...
# 1165                            PARIS 14                        NaN
# 10994                           PARIS 15                        NaN
# 7846                            PARIS 15                        NaN
# 6962                            PARIS 19                        NaN
# 11018                           PARIS 19                        NaN
#
#       fields.etatadministratifunitelegale fields.geolocetablissement  \
# 989                                Active       [48.86182, 2.435903]
# 11159                              Active       [48.86182, 2.435903]
# 11026                              Active      [48.853229, 2.389652]
# 6978                               Active      [48.853229, 2.389652]
# 11093                              Active      [48.845433, 2.321548]
# ...                                   ...                        ...
# 1165                               Active      [48.829565, 2.329143]
# 10994                              Active       [48.835341, 2.30214]
# 7846                               Active       [48.835341, 2.30214]
# 6962                               Active      [48.873641, 2.377641]
# 11018                              Active      [48.873641, 2.377641]
#
#       fields.trancheeffectifsunitelegale  \
# 989                     20 à 49 salariés
# 11159                   20 à 49 salariés
# 11026                     6 à 9 salariés
# 6978                      6 à 9 salariés
# 11093                    1 ou 2 salariés
# ...                                  ...
# 1165                                 NaN
# 10994                                NaN
# 7846                                 NaN
# 6962                                 NaN
# 11018                                NaN
#
#       fields.trancheeffectifsunitelegaletriable fields.siretsiegeunitelegale  \
# 989                                          12               31081902400293
# 11159                                        12               31081902400293
# 11026                                        03               32079827500030
# 6978                                         03               32079827500030
# 11093                                        01               32239771200017
# ...                                         ...                          ...
# 1165                                        NaN               83479403400019
# 10994                                       NaN               83526701400024
# 7846                                        NaN               83526701400024
# 6962                                        NaN               83834612000010
# 11018                                       NaN               83834612000010
#
#          fields.siret fields.etablissementsiege fields.adresseetablissement  \
# 989    31081902400293                       oui         14 Rue DE LA BEAUNE
# 11159  31081902400293                       oui         14 Rue DE LA BEAUNE
# 11026  32079827500030                       oui         10 Impasse DELEPINE
# 6978   32079827500030                       oui         10 Impasse DELEPINE
# 11093  32239771200017                       oui        103 Rue DE VAUGIRARD
# ...               ...                       ...                         ...
# 1165   83479403400019                       oui        47 Rue REMY DUMONCEL
# 10994  83526701400024                       oui             60 Rue DOMBASLE
# 7846   83526701400024                       oui             60 Rue DOMBASLE
# 6962   83834612000010                       oui        15 Rue JULES ROMAINS
# 11018  83834612000010                       oui        15 Rue JULES ROMAINS
#
#              fields.sectionunitelegale fields.codepostaletablissement  \
# 989        Hébergement et restauration                        93100.0
# 11159      Hébergement et restauration                        93100.0
# 11026  Santé humaine et action sociale                        75011.0
# 6978   Santé humaine et action sociale                        75011.0
# 11093     Autres activités de services                        75006.0
# ...                                ...                            ...
# 1165      Information et communication                        75014.0
# 10994     Autres activités de services                        75015.0
# 7846      Autres activités de services                        75015.0
# 6962      Autres activités de services                        75019.0
# 11018     Autres activités de services                        75019.0
#
#       fields.caractereemployeurunitelegale fields.datecreationunitelegale  \
# 989                                    Oui                     1973-10-30
# 11159                                  Oui                     1973-10-30
# 11026                                  Oui                     1980-08-01
# 6978                                   Oui                     1980-08-01
# 11093                                  Oui                     1981-08-01
# ...                                    ...                            ...
# 1165                                   Non                     2017-12-01
# 10994                                  Non                     2010-04-28
# 7846                                   Non                     2010-04-28
# 6962                                   Non                     2017-03-29
# 11018                                  Non                     2017-03-29
#
#       fields.datecreationetablissement  \
# 989                         2017-12-01
# 11159                       2017-12-01
# 11026                       1993-07-09
# 6978                        1993-07-09
# 11093                       1981-08-01
# ...                                ...
# 1165                        2017-12-01
# 10994                       2018-02-16
# 7846                        2018-02-16
# 6962                        2017-03-29
# 11018                       2017-03-29
#
#                       fields.denominationunitelegale geometry.type  \
# 989                              VACANCES & FAMILLES         Point
# 11159                            VACANCES & FAMILLES         Point
# 11026                                     BABILLAGES         Point
# 6978                                      BABILLAGES         Point
# 11093                                      SOS PARIS         Point
# ...                                              ...           ...
# 1165                  PARIS 14, TERRITOIRE DE CINEMA         Point
# 10994  ASSOCIATION DES COMMERCANTS DE LA RUE VOUILLE         Point
# 7846   ASSOCIATION DES COMMERCANTS DE LA RUE VOUILLE         Point
# 6962                                  ESPOIR BERBERE         Point
# 11018                                 ESPOIR BERBERE         Point
#
#         geometry.coordinates
# 989     [2.435903, 48.86182]
# 11159   [2.435903, 48.86182]
# 11026  [2.389652, 48.853229]
# 6978   [2.389652, 48.853229]
# 11093  [2.321548, 48.845433]
# ...                      ...
# 1165   [2.329143, 48.829565]
# 10994   [2.30214, 48.835341]
# 7846    [2.30214, 48.835341]
# 6962   [2.377641, 48.873641]
# 11018  [2.377641, 48.873641]
#
# [106 rows x 18 columns]

# %%
SIRENE.drop_duplicates(subset = SIRENE.drop(['geometry.coordinates', 'fields.geolocetablissement'], axis = 1).columns, inplace = True)

# %% [markdown]
# #### Missing values

# %%
SIRENE.isna().sum()
# Out:
# fields.libellecommuneetablissement              1
# fields.categorieentreprise                   4533
# fields.etatadministratifunitelegale             0
# fields.geolocetablissement                    139
# fields.trancheeffectifsunitelegale           4292
# fields.trancheeffectifsunitelegaletriable    4292
# fields.siretsiegeunitelegale                    0
# fields.siret                                    0
# fields.etablissementsiege                       0
# fields.adresseetablissement                     6
# fields.sectionunitelegale                       0
# fields.codepostaletablissement                  1
# fields.caractereemployeurunitelegale            0
# fields.datecreationunitelegale                  0
# fields.datecreationetablissement                0
# fields.denominationunitelegale                  4
# geometry.type                                 139
# geometry.coordinates                          139
# dtype: int64

# %% [markdown]
# #### fields.categorieentreprise
# Many NaNs: they are 'non productive' entities (https://www.insee.fr/fr/information/1730869)

# %%
SIRENE['fields.categorieentreprise'].fillna('Non productif', inplace = True)

# %% [markdown]
# #### fields.etatadministratifunitelegale
# Almost all entities are still active so this field is not very informative. We can drop it.

# %%
SIRENE.drop('fields.etatadministratifunitelegale', axis = 1, inplace = True)

# %% [markdown]
# #### fields.geolocetablissement
# We need to examine and potentially fill the missing values.

# %%
SIRENE[SIRENE['fields.geolocetablissement'].isna()].head()
# Out:
#     fields.libellecommuneetablissement fields.categorieentreprise  \
# 216                           PARIS 16              Non productif
# 351                           PARIS 16                        PME
# 495                           PARIS 16                        PME
# 766                           PARIS 16                        PME
# 797                           PARIS 16                        PME
#
#     fields.geolocetablissement fields.trancheeffectifsunitelegale  \
# 216                        NaN                                NaN
# 351                        NaN                    1 ou 2 salariés
# 495                        NaN                   10 à 19 salariés
# 766                        NaN                     6 à 9 salariés
# 797                        NaN                    1 ou 2 salariés
#
#     fields.trancheeffectifsunitelegaletriable fields.siretsiegeunitelegale  \
# 216                                       NaN               83405071800016
# 351                                        01               81065441800013
# 495                                        11               32765711000018
# 766                                        03               34088665400011
# 797                                        01               78467027500022
#
#        fields.siret fields.etablissementsiege fields.adresseetablissement  \
# 216  83405071800016                       oui        2 Avenue PAUL DOUMER
# 351  81065441800013                       oui  15 Avenue PRESIDENT WILSON
# 495  32765711000018                       oui      71 Avenue HENRI MARTIN
# 766  34088665400011                       oui       34 Avenue DE NEW YORK
# 797  78467027500022                       oui              27 Rue DECAMPS
#
#                      fields.sectionunitelegale fields.codepostaletablissement  \
# 216               Autres activités de services                        75116.0
# 351  Arts, spectacles et activités récréatives                        75116.0
# 495  Arts, spectacles et activités récréatives                        75116.0
# 766               Autres activités de services                        75116.0
# 797               Autres activités de services                        75116.0
#
#     fields.caractereemployeurunitelegale fields.datecreationunitelegale  \
# 216                                  Non                     2017-10-11
# 351                                  Oui                     2007-05-15
# 495                                  Oui                     1983-01-01
# 766                                  Oui                     1987-01-01
# 797                                  Oui                     1900-01-01
#
#     fields.datecreationetablissement         fields.denominationunitelegale  \
# 216                       2017-10-11                    ASSOCIATION MANASSE
# 351                       2007-05-15     ASSOCIATION QI GONG EE TONG FRANCE
# 495                       1983-01-01                   CERCLE FEMININ PARIS
# 766                       1987-01-01    AMERICAN CENTER FOR ART AND CULTURE
# 797                       1900-01-01  AUMONERIE CATHOLIQUE JANSON-DELACROIX
#
#     geometry.type geometry.coordinates
# 216           NaN                  NaN
# 351           NaN                  NaN
# 495           NaN                  NaN
# 766           NaN                  NaN
# 797           NaN                  NaN

# %%
# Are they all located in the XVIe arrondissement?
SIRENE.loc[SIRENE['fields.geolocetablissement'].isna(),'fields.codepostaletablissement'].value_counts().head()
# Out:
# 75116.0    112
# 75004.0      4
# 91080.0      2
# 75015.0      2
# 76620.0      2
# Name: fields.codepostaletablissement, dtype: int64

# %%
# Almost all of them: probably the geolocalisation was not able to deal with 75116 as 'code postal' instead of 75016.
# We will try to get the geolocation based on the address (switching 75116 to 75016).

# Subsetting
subset = SIRENE.loc[SIRENE['fields.geolocetablissement'].isna()].copy()
subset['fields.codepostaletablissement'] = np.where(subset['fields.codepostaletablissement'] == '75116.0', '75016', subset['fields.codepostaletablissement'])

# Geocoding
geolocator = Nominatim(user_agent="ParisSubsidies")

for i in subset.index:
    d = {'street':subset.loc[i,'fields.adresseetablissement'], 'postalcode': str(subset.loc[i,'fields.codepostaletablissement'])[0:5], 'country':'FRANCE'}
    p = geolocator.geocode(d)
    try:
        subset.loc[i,'fields.geolocetablissement'] = '[' + str(p.longitude) + ',' + str(p.latitude) + ']'
    except:
        pass

# %%
subset.loc[subset['fields.geolocetablissement'].isna(), ['fields.adresseetablissement', 'fields.codepostaletablissement', 'fields.denominationunitelegale']]
# Out:
#              fields.adresseetablissement fields.codepostaletablissement  \
# 2768                  DEPARTEMENTALE 128                        91190.0
# 3297         8 Place LES COPAINS D ABORD                        91080.0
# 3480   1 Place MAL DE LATTRE DE TASSIGNY                          75016
# 4570     Place MAL DE LATTRE DE TASSIGNY                          75016
# 5055   1 Place MAL DE LATTRE DE TASSIGNY                          75016
# 5156     55 Rue DU 329E RGT D'INFANTERIE                        76620.0
# 5876       7 Place M RENAUD -JL BARRAULT                        75015.0
# 6587                    PARC D'ACTIVITES                        84120.0
# 6954            5 Avenue LA GRANDE ARMEE                          75016
# 7114     55 Rue DU 329E RGT D'INFANTERIE                        76620.0
# 7714     Place MAL DE LATTRE DE TASSIGNY                          75016
# 7768             17 Rue DU 26EME DRAGONS                        21000.0
# 7968             ZAC DES CORNILLONS NORD                        93200.0
# 9092            5 Rue JOSEPH ET M HACKIN                          75016
# 9625     Place MAL DE LATTRE DE TASSIGNY                          75016
# 10360    Place MAL DE LATTRE DE TASSIGNY                          75016
#
#                           fields.denominationunitelegale
# 2768                             SYSTEM@TIC PARIS REGION
# 3297                                LES PASSEURS D'ONDES
# 3480                            ASSOCIATION SPI DAUPHINE
# 4570                                OREILLE DE  DAUPHINE
# 5055                                 THEATRE A  DAUPHINE
# 5156                              ASSOCIATION LA BAZOOKA
# 5876                                LES DONNEURS DE VOIX
# 6587                                               ACIDD
# 6954   CENTRE DE RECHERCHE INTERDISCIPLINAIRE EN JURI...
# 7114                                      COMPAGNIE AKTE
# 7714   ETUDIANTS DU MASTER MANAGEMENT DES ORGANISATIO...
# 7768                                      26000 COUVERTS
# 7968                             JUSTICE DEUXIEME CHANCE
# 9092                                                FERT
# 9625                            FLEUR DE BITUME-DAUPHINE
# 10360                                         GO TO TOGO

# %%
# Manual input for remaining NaNs
subset.loc[2768, 'fields.geolocetablissement'] = '[48.6572354,2.18586]'
subset.loc[3297, 'fields.geolocetablissement'] = '[48.6287341,2.4156858]'
subset.loc[3480, 'fields.geolocetablissement'] = '[48.8710273,2.271914]'
subset.loc[4570, 'fields.geolocetablissement'] = '[48.8710273,2.271914]'
subset.loc[5055, 'fields.geolocetablissement'] = '[48.8710273,2.271914]'
subset.loc[5156, 'fields.geolocetablissement'] = '[49.5039949,0.122207]'
subset.loc[5876, 'fields.geolocetablissement'] = '[48.8383529,2.2972237]'
subset.loc[6587, 'fields.geolocetablissement'] = '[43.7033551,5.5627938]'
subset.loc[6954, 'fields.geolocetablissement'] = '[48.8742464,2.2901752]'
subset.loc[7114, 'fields.geolocetablissement'] = '[49.5039949,0.122207]'
subset.loc[7714, 'fields.geolocetablissement'] = '[48.8710273,2.271914]'
subset.loc[7768, 'fields.geolocetablissement'] = '[47.3322116,5.0458991]'
subset.loc[7968, 'fields.geolocetablissement'] = '[48.9255848,2.3621314]'
subset.loc[9092, 'fields.geolocetablissement'] = '[48.8421348,2.3316201]'
subset.loc[9625, 'fields.geolocetablissement'] = '[48.8710273,2.271914]'
subset.loc[10360, 'fields.geolocetablissement'] = '[48.8710273,2.271914]'

# %%
# Load data into SIRENE
for i in subset.index:
    SIRENE.loc[i, 'fields.geolocetablissement'] = subset.loc[i,'fields.geolocetablissement']

# %% [markdown]
# #### fields.trancheeffectifsunitelegale & fields.trancheeffectifsunitelegaletriable
# NaNs are 'Etablissement non employeur' with triable = -1.
#
# Ordered categorical field.

# %%
SIRENE['fields.trancheeffectifsunitelegale'].fillna('Etablissement non employeur', inplace = True)
SIRENE['fields.trancheeffectifsunitelegaletriable'].fillna(-1, inplace = True)

# %%
# Convert to integer
SIRENE['fields.trancheeffectifsunitelegaletriable'] = SIRENE['fields.trancheeffectifsunitelegaletriable'].astype(int)

# %%
dct_tranche = dict()

for tranche in SIRENE['fields.trancheeffectifsunitelegale'].unique():
    dct_tranche[tranche] = int(SIRENE.loc[SIRENE.loc[SIRENE['fields.trancheeffectifsunitelegale'] == tranche].index.min(), 'fields.trancheeffectifsunitelegaletriable'])

# %%
# Sort dictionary by values
dct_tranche = dict(sorted(dct_tranche.items(), key=lambda item: item[1]))

# %%
SIRENE['fields.trancheeffectifsunitelegale'] = pd.Categorical(SIRENE['fields.trancheeffectifsunitelegale'], categories=dct_tranche.keys(), ordered = True)

# %% [markdown]
# #### fields.siretsiegeunitelegale
# Uniquely identifies legal entity.

# %% [markdown]
# #### fields.siret
# Uniquely identifies etablissement.

# %% [markdown]
# #### fields.etablissementsiege
# 'oui' if etablissement is siege.
#
# To convert to binary field 1/0.

# %%
SIRENE['fields.etablissementsiege'] = np.where(SIRENE['fields.etablissementsiege'] == 'oui',1,0)

# %% [markdown]
# #### Dates field
# Transform to datetime

# %% [markdown]
# ##### fields.datecreationunitelegale

# %%
SIRENE['fields.datecreationunitelegale'] = pd.to_datetime(SIRENE['fields.datecreationunitelegale'])

# %% [markdown]
# ##### fields.datecreationetablissement

# %%
SIRENE['fields.datecreationetablissement'] = pd.to_datetime(SIRENE['fields.datecreationetablissement'])

# %% [markdown]
# #### Address fields
# We keep them for visualisation purposes (hover labels).

# %% [markdown]
# ##### fields.adresseetablissement
# We fill the NaNs manually.

# %%
SIRENE.loc[SIRENE['fields.adresseetablissement'].isna()]
# Out:
#       fields.libellecommuneetablissement fields.categorieentreprise  \
# 1267                          LES PILLES                        PME
# 4846                 COEUVRES-ET-VALSERY                        PME
# 6327                           LOUHOSSOA                        PME
# 7612             FLEURY-DEVANT-DOUAUMONT              Non productif
# 10836                            PRASLAY                        PME
# 11123                       SOURCE-SEINE              Non productif
#
#       fields.geolocetablissement fields.trancheeffectifsunitelegale  \
# 1267       [44.379526, 5.188954]        Etablissement non employeur
# 4846       [49.335993, 3.151804]                    1 ou 2 salariés
# 6327      [43.317797, -1.355818]                   10 à 19 salariés
# 7612        [49.193794, 5.43252]        Etablissement non employeur
# 10836       [47.74088, 5.105861]                    1 ou 2 salariés
# 11123      [47.490598, 4.686979]        Etablissement non employeur
#
#        fields.trancheeffectifsunitelegaletriable fields.siretsiegeunitelegale  \
# 1267                                          -1               41763712100019
# 4846                                           1               38750560500023
# 6327                                          11               41103434100049
# 7612                                          -1               78339244200019
# 10836                                          1               47957806400012
# 11123                                         -1               50097582600016
#
#          fields.siret  fields.etablissementsiege fields.adresseetablissement  \
# 1267   41763712100019                          1                         NaN
# 4846   38750560500023                          1                         NaN
# 6327   41103434100049                          1                         NaN
# 7612   78339244200019                          1                         NaN
# 10836  47957806400012                          1                         NaN
# 11123  50097582600016                          1                         NaN
#
#                        fields.sectionunitelegale  \
# 1267                Autres activités de services
# 4846   Arts, spectacles et activités récréatives
# 6327   Arts, spectacles et activités récréatives
# 7612   Arts, spectacles et activités récréatives
# 10836  Arts, spectacles et activités récréatives
# 11123               Autres activités de services
#
#       fields.codepostaletablissement fields.caractereemployeurunitelegale  \
# 1267                         26110.0                                  Non
# 4846                          2600.0                                  Non
# 6327                         64250.0                                  Oui
# 7612                         55100.0                                  Non
# 10836                        52160.0                                  Oui
# 11123                        21690.0                                  Non
#
#       fields.datecreationunitelegale fields.datecreationetablissement  \
# 1267                      1997-11-01                       1997-11-01
# 4846                      1991-06-25                       2005-05-31
# 6327                      1996-02-26                       2008-09-20
# 7612                      1900-01-01                       1900-01-01
# 10836                     2004-10-18                       2004-10-18
# 11123                     2007-11-15                       2007-11-15
#
#             fields.denominationunitelegale geometry.type  \
# 1267              ASSOCIATION AFRICULTURES         Point
# 4846                   LA LANTERNE MAGIQUE         Point
# 6327              LE PETIT THEATRE DE PAIN         Point
# 7612          COMITE DU MEMORIAL DE VERDUN         Point
# 10836                         LES DECISIFS         Point
# 11123  ASSOCIATION DES SOURCES DE LA SEINE         Point
#
#          geometry.coordinates
# 1267    [5.188954, 44.379526]
# 4846    [3.151804, 49.335993]
# 6327   [-1.355818, 43.317797]
# 7612     [5.43252, 49.193794]
# 10836    [5.105861, 47.74088]
# 11123   [4.686979, 47.490598]

# %%
SIRENE.loc[1267, 'fields.adresseetablissement'] = 'Le Village'
SIRENE.loc[4846, 'fields.adresseetablissement'] = '28 Rue Gabrielle d\'Estrées'
SIRENE.loc[6327, 'fields.adresseetablissement'] = 'Le Bourg'
SIRENE.loc[7612, 'fields.adresseetablissement'] = '1 Avenue du Corps Européen'
SIRENE.loc[10836, 'fields.adresseetablissement'] = '2 Rue des Chassaignes'
SIRENE.loc[11123, 'fields.adresseetablissement'] = '22 Rue de Saint-Germain'

# %% [markdown]
# ##### fields.libellecommuneetablissement
# We fill the NaNs manually.

# %%
SIRENE.loc[SIRENE['fields.libellecommuneetablissement'].isna()]
# Out:
#      fields.libellecommuneetablissement fields.categorieentreprise  \
# 7622                                NaN                        PME
#
#      fields.geolocetablissement fields.trancheeffectifsunitelegale  \
# 7622      [49.028226, 3.957707]                   10 à 19 salariés
#
#       fields.trancheeffectifsunitelegaletriable fields.siretsiegeunitelegale  \
# 7622                                         11               31935615000015
#
#         fields.siret  fields.etablissementsiege fields.adresseetablissement  \
# 7622  31935615000015                          1       HOTEL DE VILLE QUEBEC
#
#          fields.sectionunitelegale fields.codepostaletablissement  \
# 7622  Autres activités de services                            NaN
#
#      fields.caractereemployeurunitelegale fields.datecreationunitelegale  \
# 7622                                  Oui                     1980-01-01
#
#      fields.datecreationetablissement  \
# 7622                       1980-01-01
#
#                 fields.denominationunitelegale geometry.type  \
# 7622  ASS INTERNATIONALE DES MAIRES FRANCOPHON         Point
#
#        geometry.coordinates
# 7622  [3.957707, 49.028226]

# %%
SIRENE.loc[7622, 'fields.libellecommuneetablissement'] = 'QUEBEC'

# %% [markdown]
# ##### fields.codepostaletablissement
# Kept first 5 characters only.

# %%
SIRENE['fields.codepostaletablissement'] = SIRENE['fields.codepostaletablissement'].astype(str).apply(lambda x: x[0:5])
SIRENE.loc[7622, 'fields.codepostaletablissement'] = 'G1R 4S9' # Except for Quebec

# %% [markdown]
# ##### Concatenate into a single field (addresseetablissementcomplete)

# %%
SIRENE['adresseetablissementcomplete'] = SIRENE['fields.adresseetablissement'] + ', ' + SIRENE['fields.codepostaletablissement'] + ' ' + SIRENE['fields.libellecommuneetablissement']
# We keep the 'code postal' for arrondissement & departement analysis
SIRENE.drop(['fields.adresseetablissement', 'fields.libellecommuneetablissement'], axis = 1, inplace = True)

# %%
# Upper case
SIRENE['adresseetablissementcomplete'] = SIRENE['adresseetablissementcomplete'].str.upper()

# %% [markdown]
# #### fields.sectionunitelegale
# Not very informative and we have more insights in the subsidies file ('Secteurs d'activités définies par l'association').
# We can drop it.

# %%
SIRENE.drop('fields.sectionunitelegale', axis = 1, inplace = True)

# %% [markdown]
# #### fields.caractereemployeurunitelegale
# 'oui' if can have employees.
#
# To convert to binary field 1/0.

# %%
SIRENE['fields.caractereemployeurunitelegale'] = np.where(SIRENE['fields.caractereemployeurunitelegale'] == 'Oui',1,0)

# %% [markdown]
# #### fields.denominationunitelegale
# We fill the NaNs manually.

# %%
SIRENE.loc[SIRENE['fields.denominationunitelegale'].isna()]
# Out:
#      fields.categorieentreprise fields.geolocetablissement  \
# 1523                        PME      [48.863613, 2.405414]
# 2498              Non productif      [48.837568, 2.259573]
# 5732                        PME      [48.890392, 2.345489]
# 5886                        PME      [48.819309, 2.343683]
#
#      fields.trancheeffectifsunitelegale  \
# 1523        Etablissement non employeur
# 2498        Etablissement non employeur
# 5732        Etablissement non employeur
# 5886        Etablissement non employeur
#
#       fields.trancheeffectifsunitelegaletriable fields.siretsiegeunitelegale  \
# 1523                                         -1               50980367200013
# 2498                                         -1               51265462500015
# 5732                                         -1               82122548900011
# 5886                                         -1               52837795500026
#
#         fields.siret  fields.etablissementsiege  \
# 1523  50980367200013                          1
# 2498  51265462500015                          1
# 5732  82122548900011                          1
# 5886  52837795500018                          0
#
#      fields.codepostaletablissement  fields.caractereemployeurunitelegale  \
# 1523                          75020                                     0
# 2498                          75016                                     0
# 5732                          75018                                     0
# 5886                          75014                                     0
#
#      fields.datecreationunitelegale fields.datecreationetablissement  \
# 1523                     2009-01-09                       2009-01-09
# 2498                     2009-06-02                       2009-06-02
# 5732                     2016-07-01                       2016-07-01
# 5886                     2009-03-16                       2009-03-16
#
#      fields.denominationunitelegale geometry.type   geometry.coordinates  \
# 1523                            NaN         Point  [2.405414, 48.863613]
# 2498                            NaN         Point  [2.259573, 48.837568]
# 5732                            NaN         Point  [2.345489, 48.890392]
# 5886                            NaN         Point  [2.343683, 48.819309]
#
#              adresseetablissementcomplete
# 1523    4  VLA DES LYANES, 75020 PARIS 20
# 2498         10 RUE GUDIN, 75016 PARIS 16
# 5732         59 RUE RAMEY, 75018 PARIS 18
# 5886  1 BOULEVARD JOURDAN, 75014 PARIS 14

# %%
SIRENE.loc[1523, 'fields.denominationunitelegale'] = 'ALESSANDRA LE DU'
SIRENE.loc[2498, 'fields.denominationunitelegale'] = 'NADIA BARBE'
SIRENE.loc[5732, 'fields.denominationunitelegale'] = 'VERONIQUE RIEFFEL'
SIRENE.loc[5886, 'fields.denominationunitelegale'] = 'AHMED LAHLOU'

# %%
# Upper case
SIRENE['fields.denominationunitelegale'] = SIRENE['fields.denominationunitelegale'].str.upper()

# %% [markdown]
# #### geometry.type and geometry.coordinates
# Redundant information with fields.geolocetablissement. We can drop them.

# %%
SIRENE.drop(['geometry.type', 'geometry.coordinates'], axis = 1, inplace = True)

# %% [markdown]
# #### Columns name
# We can remove all the 'fields.' prefixes.

# %%
SIRENE.columns = SIRENE.columns.str.replace('fields.', '', regex=False)

# %% [markdown]
# ### CLEAN VIEW

# %% [markdown]
# #### Profile report after cleaning

# %%
SIRENE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11108 entries, 0 to 11156
# Data columns (total 13 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   categorieentreprise                 11108 non-null  object
#  1   geolocetablissement                 11108 non-null  object
#  2   trancheeffectifsunitelegale         11108 non-null  category
#  3   trancheeffectifsunitelegaletriable  11108 non-null  int64
#  4   siretsiegeunitelegale               11108 non-null  object
#  5   siret                               11108 non-null  object
#  6   etablissementsiege                  11108 non-null  int64
#  7   codepostaletablissement             11108 non-null  object
#  8   caractereemployeurunitelegale       11108 non-null  int64
#  9   datecreationunitelegale             11108 non-null  datetime64[ns]
#  10  datecreationetablissement           11108 non-null  datetime64[ns]
#  11  denominationunitelegale             11108 non-null  object
#  12  adresseetablissementcomplete        11108 non-null  object
# dtypes: category(1), datetime64[ns](2), int64(3), object(7)
# memory usage: 1.4+ MB

# %%
#profile = ProfileReport(SIRENE.reset_index(drop=True), title='SIRENE Profiling Report - Before Cleaning', interactions={'continuous': False})
#profile.to_file('ProfileReports/ParisSubsidies_SIRENE_bf.html')

# %% [markdown]
# #### Save to CSV

# %%
SIRENE.to_csv('../00_DataFiles/02_Cleaned/ParisSubsidies_SIRENE.csv', index = False)

# %% [markdown]
# #### Save to Feather

# %%
SIRENE.reset_index(drop=True).to_feather('../00_DataFiles/02_Cleaned/ParisSubsidies_SIRENE.feather')
