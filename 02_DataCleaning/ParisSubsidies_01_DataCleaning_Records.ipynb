# %% [markdown]
# ## PARIS SUBSIDIES: DATA CLEANING (RECORDS)

# %% [markdown]
# ### LIBRAIRIES IMPORT

# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

# %% [markdown]
# ### DATA IMPORT

# %%
subsidies = pd.read_csv('../00_DataFiles/01_Collected/ParisSubsidies_Records.csv')
subsidies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79973 entries, 0 to 79972
# Data columns (total 10 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Numéro de dossier                                79973 non-null  object
#  1   Année budgétaire                                 79973 non-null  int64
#  2   Collectivité                                     79973 non-null  object
#  3   Nom Bénéficiaire                                 79973 non-null  object
#  4   Numéro Siret                                     79973 non-null  int64
#  5   Objet du dossier                                 79973 non-null  object
#  6   Montant voté                                     79973 non-null  int64
#  7   Direction                                        79973 non-null  object
#  8   Nature de la subvention                          79973 non-null  object
#  9   Secteurs d'activités définies par l'association  79948 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 6.1+ MB

# %% [markdown]
# #### Profile report before cleaning

# %%
profile = ProfileReport(subsidies.reset_index(drop=True), title="Paris Subsidies Profiling Report - Before Cleaning")
profile.to_file("ProfileReports/ParisSubsidies_Records_bf.html")
# Out:
# Summarize dataset: 100%|██████████| 33/33 [00:05<00:00,  6.01it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  3.14it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 897.75it/s]

# %% [markdown]
# ### FIELD BY FIELD APPROACH

# %% [markdown]
# ### Missing values

# %%
subsidies.isna().sum()
# Out:
# Numéro de dossier                                   0
# Année budgétaire                                    0
# Collectivité                                        0
# Nom Bénéficiaire                                    0
# Numéro Siret                                        0
# Objet du dossier                                    0
# Montant voté                                        0
# Direction                                           0
# Nature de la subvention                             0
# Secteurs d'activités définies par l'association    25
# dtype: int64

# %% [markdown]
# #### Numéro de dossier
# Despite high cardinality, we will keep the field so we can offer the possibility to retrieve a Paris City Council's deliberation from http://a06.apps.paris.fr/a06/jsp/site/Portal.jsp?page=search-solr
#
# However, it should be unique for each record but some are present in two records, for instance '2019_07725'.

# %%
subsidies.loc[subsidies['Numéro de dossier'] == '2019_07725']
# Out:
#       Numéro de dossier  Année budgétaire    Collectivité Nom Bénéficiaire  \
# 40773        2019_07725              2019  Ville de Paris          FOODLAB
# 59337        2019_07725              2020  Ville de Paris          FOODLAB
#
#          Numéro Siret                                   Objet du dossier  \
# 40773  81850945700011  Un Foodlab rue de Mouzaia : Maison de l'alimen...
# 59337  81850945700011  Un Foodlab rue de Mouzaia : Maison de l'alimen...
#
#        Montant voté Direction Nature de la subvention  \
# 40773             0     DASES            Non précisée
# 59337        100000     DASES          Investissement
#
#          Secteurs d'activités définies par l'association
# 40773  Education & formation;Précarité & Exclusion;Vi...
# 59337  Education & formation;Précarité & Exclusion;Vi...

# %% [markdown]
# Let's list all the seemingly duplicates

# %%
mask_duplicates = subsidies.duplicated(subset = 'Numéro de dossier', keep=False)
subsidies.loc[mask_duplicates].sort_values(by=['Numéro de dossier', 'Montant voté'])
# Out:
#       Numéro de dossier  Année budgétaire    Collectivité  \
# 49587        2017_04250              2017  Ville de Paris
# 60269        2017_04250              2020  Ville de Paris
# 31022        2018_00414              2018  Ville de Paris
# 66573        2018_00414              2020  Ville de Paris
# 15095        2018_04293              2018  Ville de Paris
# 61           2018_04293              2019  Ville de Paris
# 78652        2018_06960              2019  Ville de Paris
# 58552        2018_06960              2020  Ville de Paris
# 40360        2019_01028              2019  Ville de Paris
# 62132        2019_01028              2020  Ville de Paris
# 98           2019_02520              2020  Ville de Paris
# 41481        2019_02520              2019  Ville de Paris
# 42834        2019_04634              2019  Ville de Paris
# 62493        2019_04634              2020  Ville de Paris
# 43139        2019_05270              2019  Ville de Paris
# 65367        2019_05270              2020  Ville de Paris
# 57393        2019_05351              2019  Ville de Paris
# 61418        2019_05351              2020  Ville de Paris
# 40773        2019_07725              2019  Ville de Paris
# 59337        2019_07725              2020  Ville de Paris
# 41462        2019_09377              2019  Ville de Paris
# 71893        2019_09377              2021  Ville de Paris
# 44967        2019_09840              2019  Ville de Paris
# 60988        2019_09840              2020  Ville de Paris
# 78900        2019_10171              2019  Ville de Paris
# 62121        2019_10171              2020  Ville de Paris
# 78521        2019_10179              2019  Ville de Paris
# 65718        2019_10179              2020  Ville de Paris
# 44919        2020_00258              2019  Ville de Paris
# 57826        2020_00258              2020  Ville de Paris
# 57996        2020_00339              2020  Ville de Paris
# 72263        2020_00339              2021  Ville de Paris
# 64506        2020_00789              2020  Ville de Paris
# 69417        2020_00789              2021  Ville de Paris
# 64611        2020_08294              2020  Ville de Paris
# 73348        2020_08294              2021  Ville de Paris
# 58858        2020_10345              2020  Ville de Paris
# 68526        2020_10345              2021  Ville de Paris
# 68655        2021_00774              2021  Ville de Paris
# 60484        2021_00774              2020  Ville de Paris
#
#                                         Nom Bénéficiaire    Numéro Siret  \
# 49587                                         RED'S TEAM  50752562400015
# 60269                                         RED S TEAM  50752562400015
# 31022                                  MELTIN'CLUB PARIS  79109293500018
# 66573                         MELTIN'CLUB PARIS (M.C.P.)  79109293500018
# 15095                        AGENCE PARISIENNE DU CLIMAT  52800732100011
# 61                     AGENCE PARISIENNE DU CLIMAT (APC)  52800732100011
# 78652                    CERCLE DE TAEKWONDO DES ARCHERS  79805014200024
# 58552                    CERCLE DE TAEKWONDO DES ARCHERS  79805014200024
# 40360                                        ATOUTPRISES  44806320600024
# 62132                                        ATOUTPRISES  44806320600024
# 98                  ASSOCIATION DROITS ET HABITATS - ADH  48361649600012
# 41481                        COMITE ACTIONS LOGEMENT CAL  48361649600012
# 42834                                          PLUS LOIN  39344280100048
# 62493                                          PLUS LOIN  39344280100048
# 43139  COMITE DEPARTEMENTAL DE CYCLOTOURISME DE PARIS...  44768027300029
# 65367  COMITE DEPARTEMENTAL DE CYCLOTOURISME DE PARIS...  44768027300029
# 57393                          LA PETANQUE BATIGNOLLAISE  51516585000014
# 61418                          LA PETANQUE BATIGNOLLAISE  51516585000014
# 40773                                            FOODLAB  81850945700011
# 59337                                            FOODLAB  81850945700011
# 41462                                  EMMAUS SOLIDARITE  31723624800017
# 71893                                  EMMAUS SOLIDARITE  31723624800017
# 44967              FONDS POUR LES FEMMES EN MEDITERRANEE  50525407800049
# 60988              FONDS POUR LES FEMMES EN MEDITERRANEE  50525407800049
# 78900                               MEMORIAL DE LA SHOAH  78424378400013
# 62121                               MEMORIAL DE LA SHOAH  78424378400013
# 78521                                   12 BARS EN SCENE  84990772000015
# 65718                                   12 BARS EN SCENE  84990772000015
# 44919                                 EIFFEL BASKET CLUB  44808025900014
# 57826                                 EIFFEL BASKET CLUB  44808025900022
# 57996                 ACADEMIE FOOTBALL PARIS 18 (AFP18)  81111744900025
# 72263                 ACADEMIE FOOTBALL PARIS 18 (AFP18)  81111744900025
# 64506                   JEUNESSE ATHLETIQUE DE MONTROUGE  34488029900039
# 69417                   JEUNESSE ATHLETIQUE DE MONTROUGE  34488029900039
# 64611                                 MAESTRA PRODUCTION  88148534600012
# 73348                            MANIFEST CREATION  (MC)  88148534600020
# 58858  13ONZE15 : FRATERNITE ET VERITE (ASSOCIATION D...  81979246600024
# 68526  13ONZE15 : FRATERNITE ET VERITE (ASSOCIATION D...  81979246600024
# 68655  ASSOCIATION DE PREVENTION DU SITE DE LA VILLET...  34063517600019
# 60484  ASSOCIATION DE PREVENTION DU SITE DE LA VILLET...  34063517600019
#
#                                         Objet du dossier  Montant voté  \
# 49587                             Convention d'Objectifs             0
# 60269                             EDUCATION PAR LE SPORT         16000
# 31022                           Fonctionnement 2017/2018             0
# 66573                                Fonctionnement 2020          7000
# 15095                        Subvention DEVE-DLH-DU 2018             0
# 61                                            solde 2019         81250
# 78652  Projets locaux de réussite éducative, appel à ...             0
# 58552  Projets locaux de réussite éducative, appel à ...          4000
# 40360  Renouvellement de voies des murs d'escalade du...             0
# 62132  Renouvellement de voies des murs d'escalade du...          2000
# 98     Accompagner les ménages fragiles et mal logés ...             0
# 41481  CPO DASES SILPEX -  ACCOMPAGNER INDIVIDUELLEME...          2000
# 42834               Convention Espace de proximité DASES         41300
# 62493                                subvention covid-19         41300
# 43139     Projet de création d'un espace Vélo & Mobilité             0
# 65367     Projet de création d'un espace Vélo & Mobilité          3000
# 57393                             continuité association             0
# 61418                             continuité association           900
# 40773  Un Foodlab rue de Mouzaia : Maison de l'alimen...             0
# 59337  Un Foodlab rue de Mouzaia : Maison de l'alimen...        100000
# 41462                          Espace Femmes - ESI Agora             0
# 71893      Espace Femmes - ESI Agora BUDGET PARTICIPATIF             0
# 44967  Rencontre de réflexion stratégique du mouvemen...             0
# 60988  Rencontre de réflexion stratégique du mouvemen...          4000
# 78900  Travaux de déplombage - hôtel de Chalons-Luxem...             0
# 62121  Travaux de déplombage - hôtel de Chalons-Luxem...       1000000
# 78521  Demande de subvention pour le festival d'Art e...             0
# 65718  Demande de subvention pour le festival d'Art e...          7000
# 44919  Fonctionnement de l'association pour la saison...          2000
# 57826  Fonctionnement de l'association pour la saison...          2000
# 57996                        SUBVENTION EQUIPEMENT AFP18             0
# 72263                 subvention exceptionnelle covid-19          3000
# 64506                          CREATION SECTION HANDICAP             0
# 69417                 subvention exceptionnelle covid-19          3000
# 64611                          Création pièce de théâtre             0
# 73348                          Création pièce de théâtre             0
# 58858  Demande exceptionnelle  dans le cadre des 5 an...             0
# 68526  Demande exceptionnelle  dans le cadre des 5 an...         10000
# 68655  Education à l'image à la Villette. Stage en mi...         28570
# 60484  Education à l'image à la Villette. Stage en mi...         28591
#
#       Direction Nature de la subvention  \
# 49587       DJS            Non précisée
# 60269       DJS          Fonctionnement
# 31022       DJS          Fonctionnement
# 66573       DJS                  Projet
# 15095        DU            Non précisée
# 61         DEVE                  Projet
# 78652       DJS            Non précisée
# 58552        SG                  Projet
# 40360       DJS            Non précisée
# 62132       DJS          Fonctionnement
# 98         DDCT                  Projet
# 41481      DDCT                  Projet
# 42834       DJS            Non précisée
# 62493       DJS                  Projet
# 43139       DJS            Non précisée
# 65367       DJS                  Projet
# 57393       DJS          Fonctionnement
# 61418       DJS          Fonctionnement
# 40773     DASES            Non précisée
# 59337     DASES          Investissement
# 41462     DASES            Non précisée
# 71893     DASES            Non précisée
# 44967      DDCT            Non précisée
# 60988      DDCT                  Projet
# 78900       DAC          Investissement
# 62121       DAC          Investissement
# 78521       DAC            Non précisée
# 65718       DAC          Fonctionnement
# 44919       DJS          Fonctionnement
# 57826       DJS          Fonctionnement
# 57996       DJS            Non précisée
# 72263       DJS                  Projet
# 64506       DJS            Non précisée
# 69417       DJS          Fonctionnement
# 64611       DAC            Non précisée
# 73348       DAC            Non précisée
# 58858      DPSP            Non précisée
# 68526      DPMP                  Projet
# 68655      DPMP                  Projet
# 60484      DPSP                  Projet
#
#          Secteurs d'activités définies par l'association
# 49587                 Education & formation;Social;Sport
# 60269                 Education & formation;Social;Sport
# 31022          Humanitaire;Sport;Vie et animation locale
# 66573          Humanitaire;Sport;Vie et animation locale
# 15095  Architecture & urbanisme;Déplacements et trans...
# 61     Architecture & urbanisme;Déplacements et trans...
# 78652                                            Loisirs
# 58552                                            Loisirs
# 40360                      Sport;Vie et animation locale
# 62132                      Sport;Vie et animation locale
# 98     Défense des droits et des intérêts;Précarité &...
# 41481  Défense des droits et des intérêts;Précarité &...
# 42834             Loisirs;Social;Vie et animation locale
# 62493             Loisirs;Social;Vie et animation locale
# 43139                             Loisirs;Sport;Tourisme
# 65367                             Loisirs;Sport;Tourisme
# 57393              Loisirs;Sport;Vie et animation locale
# 61418              Loisirs;Sport;Vie et animation locale
# 40773  Education & formation;Précarité & Exclusion;Vi...
# 59337  Education & formation;Précarité & Exclusion;Vi...
# 41462           Humanitaire;Précarité & Exclusion;Social
# 71893           Humanitaire;Précarité & Exclusion;Social
# 44967  Aides aux associations;Défense des droits et d...
# 60988  Aides aux associations;Défense des droits et d...
# 78900                                            Mémoire
# 62121                                            Mémoire
# 78521             Culture & Arts;Vie et animation locale
# 65718             Culture & Arts;Vie et animation locale
# 44919                                              Sport
# 57826                                              Sport
# 57996         Culture & Arts;Education & formation;Sport
# 72263         Culture & Arts;Education & formation;Sport
# 64506                                              Sport
# 69417                                              Sport
# 64611                                     Culture & Arts
# 73348                                     Culture & Arts
# 58858                                             Social
# 68526                                             Social
# 68655  Education & formation;Emploi;Précarité & Exclu...
# 60484  Education & formation;Emploi;Précarité & Exclu...

# %%
# Save indices into list
mask_duplicates_index = subsidies.loc[mask_duplicates].index

# DataFrame to store dropped duplicates
df_duplicates = pd.DataFrame()

# Drop all lines with 'Montant voté' = 0 if they are a duplicate of a line with 'Montant voté' > 0
lst_duplicates_0 = list()


for i in mask_duplicates_index:
    j = subsidies.loc[subsidies['Numéro de dossier'] == subsidies.loc[i, 'Numéro de dossier']].index.to_list()
    j.remove(i)
    j = j[0]
    if subsidies.loc[i, 'Montant voté'] == 0 and subsidies.loc[j, 'Montant voté'] > 0:
        lst_duplicates_0.append(i)


df_duplicates = pd.concat([df_duplicates,subsidies.loc[lst_duplicates_0]], ignore_index=True)
subsidies.drop(lst_duplicates_0, axis = 0, inplace = True)

# %%
# Remaining duplicates
mask_duplicates = subsidies.duplicated(subset = 'Numéro de dossier', keep=False)
subsidies.loc[mask_duplicates].sort_values(by=['Numéro de dossier', 'Montant voté'])
# Out:
#       Numéro de dossier  Année budgétaire    Collectivité  \
# 42834        2019_04634              2019  Ville de Paris
# 62493        2019_04634              2020  Ville de Paris
# 41462        2019_09377              2019  Ville de Paris
# 71893        2019_09377              2021  Ville de Paris
# 44919        2020_00258              2019  Ville de Paris
# 57826        2020_00258              2020  Ville de Paris
# 64611        2020_08294              2020  Ville de Paris
# 73348        2020_08294              2021  Ville de Paris
# 68655        2021_00774              2021  Ville de Paris
# 60484        2021_00774              2020  Ville de Paris
#
#                                         Nom Bénéficiaire    Numéro Siret  \
# 42834                                          PLUS LOIN  39344280100048
# 62493                                          PLUS LOIN  39344280100048
# 41462                                  EMMAUS SOLIDARITE  31723624800017
# 71893                                  EMMAUS SOLIDARITE  31723624800017
# 44919                                 EIFFEL BASKET CLUB  44808025900014
# 57826                                 EIFFEL BASKET CLUB  44808025900022
# 64611                                 MAESTRA PRODUCTION  88148534600012
# 73348                            MANIFEST CREATION  (MC)  88148534600020
# 68655  ASSOCIATION DE PREVENTION DU SITE DE LA VILLET...  34063517600019
# 60484  ASSOCIATION DE PREVENTION DU SITE DE LA VILLET...  34063517600019
#
#                                         Objet du dossier  Montant voté  \
# 42834               Convention Espace de proximité DASES         41300
# 62493                                subvention covid-19         41300
# 41462                          Espace Femmes - ESI Agora             0
# 71893      Espace Femmes - ESI Agora BUDGET PARTICIPATIF             0
# 44919  Fonctionnement de l'association pour la saison...          2000
# 57826  Fonctionnement de l'association pour la saison...          2000
# 64611                          Création pièce de théâtre             0
# 73348                          Création pièce de théâtre             0
# 68655  Education à l'image à la Villette. Stage en mi...         28570
# 60484  Education à l'image à la Villette. Stage en mi...         28591
#
#       Direction Nature de la subvention  \
# 42834       DJS            Non précisée
# 62493       DJS                  Projet
# 41462     DASES            Non précisée
# 71893     DASES            Non précisée
# 44919       DJS          Fonctionnement
# 57826       DJS          Fonctionnement
# 64611       DAC            Non précisée
# 73348       DAC            Non précisée
# 68655      DPMP                  Projet
# 60484      DPSP                  Projet
#
#          Secteurs d'activités définies par l'association
# 42834             Loisirs;Social;Vie et animation locale
# 62493             Loisirs;Social;Vie et animation locale
# 41462           Humanitaire;Précarité & Exclusion;Social
# 71893           Humanitaire;Précarité & Exclusion;Social
# 44919                                              Sport
# 57826                                              Sport
# 64611                                     Culture & Arts
# 73348                                     Culture & Arts
# 68655  Education & formation;Emploi;Précarité & Exclu...
# 60484  Education & formation;Emploi;Précarité & Exclu...

# %%
# Manual drop
lst_duplicates_1 = [62493, 41462, 44919, 73348, 60484]
df_duplicates = pd.concat([df_duplicates,subsidies.loc[lst_duplicates_1]], ignore_index=True)
subsidies.drop(lst_duplicates_1, axis = 0, inplace = True)
df_duplicates.to_csv('../00_DataFiles/99_Dropped/ParisSubsidies_Duplicates.csv')

# %% [markdown]
# ### Année budgétaire
# We keep the field

# %% [markdown]
# ### Collectivité
# We do not need the field: it used to make sense only before 2016 when Paris City Council was split between 'Mairie de Paris' and 'Département de Paris'

# %%
subsidies.drop('Collectivité', axis = 1, inplace=True)

# %% [markdown]
# ### Nom Bénéficiaire
# We will not use this field but instead take the name from the SIRENE database for consistency (prevents typos)

# %%
subsidies.drop('Nom Bénéficiaire', axis = 1, inplace=True)

# %% [markdown]
# ### Numéro Siret
# Essential field as uniquely identifies the beneficiairies and will be used as the key to join the SIRENE data

# %% [markdown]
# ### Objet du dossier
# To keep and to be treated with NLP tools

# %% [markdown]
# ### Montant voté
# Correctly identified as of integer type

# %% [markdown]
# ### Direction
# To keep for categorical analysis (not ordinal)

# %% [markdown]
# ### Nature de la subvention
# 4 categories: Projet, Fonctionnement, Investissement, and Non Précisée

# %% [markdown]
# ### Secteurs d'activités définies par l'association
# String type but should be list

# %%
# First we need to fill NaNs
subsidies.loc[subsidies['Secteurs d\'activités définies par l\'association'].isna(), 'Numéro Siret'].unique()
# Out:
# array([45047976100030, 75170501300025, 79755853300015, 48469647100024,
#        48209742500037, 85211596300013, 48467532700023, 78430883500015])

# %%
# Manual input
subsidies.loc[subsidies['Numéro Siret'] == 45047976100030, 'Secteurs d\'activités définies par l\'association'] = 'Culture & Arts'
subsidies.loc[subsidies['Numéro Siret'] == 75170501300025, 'Secteurs d\'activités définies par l\'association'] = 'Culture & Arts'
subsidies.loc[subsidies['Numéro Siret'] == 79755853300015, 'Secteurs d\'activités définies par l\'association'] = 'Social'
subsidies.loc[subsidies['Numéro Siret'] == 48469647100024, 'Secteurs d\'activités définies par l\'association'] = 'Culture & Arts'
subsidies.loc[subsidies['Numéro Siret'] == 48209742500037, 'Secteurs d\'activités définies par l\'association'] = 'Défense des droits et des intérêts'
subsidies.loc[subsidies['Numéro Siret'] == 85211596300013, 'Secteurs d\'activités définies par l\'association'] = 'Relations internationales'
subsidies.loc[subsidies['Numéro Siret'] == 48467532700023, 'Secteurs d\'activités définies par l\'association'] = 'Vie et animation locale'
subsidies.loc[subsidies['Numéro Siret'] == 78430883500015, 'Secteurs d\'activités définies par l\'association'] = 'Sport'

# %%
subsidies['Secteurs d\'activités définies par l\'association'] = subsidies['Secteurs d\'activités définies par l\'association'].str.split(';')

# %%
subsidies.head()
# Out:
#   Numéro de dossier  Année budgétaire    Numéro Siret  \
# 0        2020_07586              2020  48905531900029
# 1        2020_08053              2020  48905531900029
# 2        2020_04885              2020  81147565600013
# 3        2020_05032              2020  48909505900015
# 4        2020_02992              2020  34482479200032
#
#                                     Objet du dossier  Montant voté Direction  \
# 0  Co-financement DDCT d'un poste adultes-relais ...          4700      DDCT
# 1                               CS 2020/DASES SEPLEX        209692     DASES
# 2                              Ressourcerie Ephémère             0       DAE
# 3  De Mômes et d'opérette : Des grottes de Lascau...             0     DASCO
# 4  Fonctionnement 2020 cité des ours 14 cité fala...        217134      DFPE
#
#   Nature de la subvention    Secteurs d'activités définies par l'association
# 0          Fonctionnement         [Loisirs, Social, Vie et animation locale]
# 1          Fonctionnement         [Loisirs, Social, Vie et animation locale]
# 2            Non précisée  [Environnement & écologie, Sport, Vie et anima...
# 3            Non précisée                    [Culture & Arts, Social, Sport]
# 4          Fonctionnement             [Education & formation, Santé, Social]

# %% [markdown]
# ## SAVE

# %% [markdown]
# ### Profile report after cleaning

# %%
profile = ProfileReport(subsidies.reset_index(drop=True), title="Paris Subsidies Profiling Report - After Cleaning")
profile.to_file("ProfileReports/ParisSubsidies_Records_af.html")
# Out:
# Summarize dataset: 100%|██████████| 30/30 [00:03<00:00,  8.78it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:00<00:00,  1.40it/s]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  4.66it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 600.99it/s]

# %% [markdown]
# ### CSV

# %%
subsidies.to_csv('../00_DataFiles/02_Cleaned/ParisSubsidies_Records.csv', index = False)
