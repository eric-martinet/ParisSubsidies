# %% [markdown]
# ## PARIS SUBSIDIES: DATA CLEANING (SIRENE)

# %% [markdown]
# ### LIBRAIRIES IMPORT

# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %% [markdown]
# ### DATA IMPORT

# %%
SIRENE = pd.read_csv('../00_DataFiles/01_Collected/ParisSubsidies_SIRENE.csv')
SIRENE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11161 entries, 0 to 11160
# Data columns (total 18 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   fields.libellecommuneetablissement         11160 non-null  object
#  1   fields.categorieentreprise                 6609 non-null   object
#  2   fields.etatadministratifunitelegale        11161 non-null  object
#  3   fields.geolocetablissement                 11021 non-null  object
#  4   fields.trancheeffectifsunitelegale         6850 non-null   object
#  5   fields.trancheeffectifsunitelegaletriable  6850 non-null   float64
#  6   fields.siretsiegeunitelegale               11161 non-null  int64
#  7   fields.siret                               11161 non-null  int64
#  8   fields.etablissementsiege                  11161 non-null  object
#  9   fields.adresseetablissement                11155 non-null  object
#  10  fields.sectionunitelegale                  11161 non-null  object
#  11  fields.codepostaletablissement             11160 non-null  float64
#  12  fields.caractereemployeurunitelegale       11161 non-null  object
#  13  fields.datecreationunitelegale             11161 non-null  object
#  14  fields.datecreationetablissement           11161 non-null  object
#  15  fields.denominationunitelegale             11157 non-null  object
#  16  geometry.type                              11021 non-null  object
#  17  geometry.coordinates                       11021 non-null  object
# dtypes: float64(2), int64(2), object(14)
# memory usage: 1.5+ MB

# %% [markdown]
# #### Profile report before cleaning

# %%
profile = ProfileReport(SIRENE.reset_index(drop=True), title="SIRENE Profiling Report - Before Cleaning")
profile.to_file("ProfileReports/ParisSubsidies_SIRENE_bf.html")
# Out:
# Summarize dataset: 100%|██████████| 49/49 [00:04<00:00, 10.28it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:01<00:00,  1.51s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.03it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 459.35it/s]

# %% [markdown]
# ### FIELD BY FIELD APPROACH

# %% [markdown]
# ### Duplicates

# %%
SIRENE.loc[SIRENE.duplicated(keep = False)].sort_values(by='fields.siret')
# Out:
#       fields.libellecommuneetablissement fields.categorieentreprise  \
# 989                            MONTREUIL                        PME
# 11159                          MONTREUIL                        PME
# 11026                           PARIS 11                        PME
# 6978                            PARIS 11                        PME
# 11093                            PARIS 6                        PME
# ...                                  ...                        ...
# 1165                            PARIS 14              Non productif
# 10994                           PARIS 15              Non productif
# 7846                            PARIS 15              Non productif
# 6962                            PARIS 19              Non productif
# 11018                           PARIS 19              Non productif
#
#       fields.geolocetablissement fields.trancheeffectifsunitelegale  \
# 989         [48.86182, 2.435903]                   20 à 49 salariés
# 11159       [48.86182, 2.435903]                   20 à 49 salariés
# 11026      [48.853229, 2.389652]                     6 à 9 salariés
# 6978       [48.853229, 2.389652]                     6 à 9 salariés
# 11093      [48.845433, 2.321548]                    1 ou 2 salariés
# ...                          ...                                ...
# 1165       [48.829565, 2.329143]        Etablissement non employeur
# 10994       [48.835341, 2.30214]        Etablissement non employeur
# 7846        [48.835341, 2.30214]        Etablissement non employeur
# 6962       [48.873641, 2.377641]        Etablissement non employeur
# 11018      [48.873641, 2.377641]        Etablissement non employeur
#
#        fields.trancheeffectifsunitelegaletriable  \
# 989                                         12.0
# 11159                                       12.0
# 11026                                        3.0
# 6978                                         3.0
# 11093                                        1.0
# ...                                          ...
# 1165                                        -1.0
# 10994                                       -1.0
# 7846                                        -1.0
# 6962                                        -1.0
# 11018                                       -1.0
#
#        fields.siretsiegeunitelegale    fields.siret fields.etablissementsiege  \
# 989                  31081902400293  31081902400293                       oui
# 11159                31081902400293  31081902400293                       oui
# 11026                32079827500030  32079827500030                       oui
# 6978                 32079827500030  32079827500030                       oui
# 11093                32239771200017  32239771200017                       oui
# ...                             ...             ...                       ...
# 1165                 83479403400019  83479403400019                       oui
# 10994                83526701400024  83526701400024                       oui
# 7846                 83526701400024  83526701400024                       oui
# 6962                 83834612000010  83834612000010                       oui
# 11018                83834612000010  83834612000010                       oui
#
#       fields.adresseetablissement fields.codepostaletablissement  \
# 989           14 Rue DE LA BEAUNE                        93100.0
# 11159         14 Rue DE LA BEAUNE                        93100.0
# 11026         10 Impasse DELEPINE                        75011.0
# 6978          10 Impasse DELEPINE                        75011.0
# 11093        103 Rue DE VAUGIRARD                        75006.0
# ...                           ...                            ...
# 1165         47 Rue REMY DUMONCEL                        75014.0
# 10994             60 Rue DOMBASLE                        75015.0
# 7846              60 Rue DOMBASLE                        75015.0
# 6962         15 Rue JULES ROMAINS                        75019.0
# 11018        15 Rue JULES ROMAINS                        75019.0
#
#       fields.caractereemployeurunitelegale fields.datecreationunitelegale  \
# 989                                    Oui                     1973-10-30
# 11159                                  Oui                     1973-10-30
# 11026                                  Oui                     1980-08-01
# 6978                                   Oui                     1980-08-01
# 11093                                  Oui                     1981-08-01
# ...                                    ...                            ...
# 1165                                   Non                     2017-12-01
# 10994                                  Non                     2010-04-28
# 7846                                   Non                     2010-04-28
# 6962                                   Non                     2017-03-29
# 11018                                  Non                     2017-03-29
#
#       fields.datecreationetablissement  \
# 989                         2017-12-01
# 11159                       2017-12-01
# 11026                       1993-07-09
# 6978                        1993-07-09
# 11093                       1981-08-01
# ...                                ...
# 1165                        2017-12-01
# 10994                       2018-02-16
# 7846                        2018-02-16
# 6962                        2017-03-29
# 11018                       2017-03-29
#
#                       fields.denominationunitelegale
# 989                              VACANCES & FAMILLES
# 11159                            VACANCES & FAMILLES
# 11026                                     BABILLAGES
# 6978                                      BABILLAGES
# 11093                                      SOS PARIS
# ...                                              ...
# 1165                  PARIS 14, TERRITOIRE DE CINEMA
# 10994  ASSOCIATION DES COMMERCANTS DE LA RUE VOUILLE
# 7846   ASSOCIATION DES COMMERCANTS DE LA RUE VOUILLE
# 6962                                  ESPOIR BERBERE
# 11018                                 ESPOIR BERBERE
#
# [106 rows x 14 columns]

# %%
SIRENE.drop_duplicates(inplace = True)

# %% [markdown]
# ### Missing values

# %%
SIRENE.isna().sum()
# Out:
# fields.libellecommuneetablissement              1
# fields.categorieentreprise                   4552
# fields.etatadministratifunitelegale             0
# fields.geolocetablissement                    140
# fields.trancheeffectifsunitelegale           4311
# fields.trancheeffectifsunitelegaletriable    4311
# fields.siretsiegeunitelegale                    0
# fields.siret                                    0
# fields.etablissementsiege                       0
# fields.adresseetablissement                     6
# fields.sectionunitelegale                       0
# fields.codepostaletablissement                  1
# fields.caractereemployeurunitelegale            0
# fields.datecreationunitelegale                  0
# fields.datecreationetablissement                0
# fields.denominationunitelegale                  4
# geometry.type                                 140
# geometry.coordinates                          140
# dtype: int64

# %% [markdown]
# ### fields.libellecommuneetablissement
# We keep it for visualisation purposes (hover labels).
#
# We might also need it to complete the NaNs of fields.geolocetablissement.
#
# We just need to complete the missing data.

# %%
SIRENE.loc[SIRENE['fields.libellecommuneetablissement'].isna()]
# Out:
#      fields.libellecommuneetablissement fields.categorieentreprise  \
# 7622                                NaN                        PME
#
#      fields.geolocetablissement fields.trancheeffectifsunitelegale  \
# 7622      [49.028226, 3.957707]                   10 à 19 salariés
#
#       fields.trancheeffectifsunitelegaletriable  fields.siretsiegeunitelegale  \
# 7622                                       11.0                31935615000015
#
#         fields.siret fields.etablissementsiege fields.adresseetablissement  \
# 7622  31935615000015                       oui       HOTEL DE VILLE QUEBEC
#
#          fields.sectionunitelegale  fields.codepostaletablissement  \
# 7622  Autres activités de services                             NaN
#
#      fields.caractereemployeurunitelegale fields.datecreationunitelegale  \
# 7622                                  Oui                     1980-01-01
#
#      fields.datecreationetablissement  \
# 7622                       1980-01-01
#
#                 fields.denominationunitelegale
# 7622  ASS INTERNATIONALE DES MAIRES FRANCOPHON

# %%
SIRENE.loc[7622, 'fields.libellecommuneetablissement'] = 'QUEBEC'
SIRENE.loc[7622, 'fields.codepostaletablissement'] = 'G1R 4S9'

# %% [markdown]
# ### fields.categorieentreprise
# Many NaNs: they are 'non productive' entities (https://www.insee.fr/fr/information/1730869)

# %%
SIRENE['fields.categorieentreprise'].fillna('Non productif', inplace = True)

# %% [markdown]
# ### fields.etatadministratifunitelegale
# Almost all entities are still active so field is not very informative, we can drop it.

# %%
SIRENE.drop('fields.etatadministratifunitelegale', axis = 1, inplace = True)

# %% [markdown]
# ### fields.geolocetablissement
# We need to examine and potentially fill the missing values

# %%
SIRENE[SIRENE['fields.geolocetablissement'].isna()].head()
# Out:
#     fields.libellecommuneetablissement fields.categorieentreprise  \
# 216                           PARIS 16              Non productif
# 351                           PARIS 16                        PME
# 495                           PARIS 16                        PME
# 766                           PARIS 16                        PME
# 797                           PARIS 16                        PME
#
#     fields.geolocetablissement fields.trancheeffectifsunitelegale  \
# 216                        NaN                                NaN
# 351                        NaN                    1 ou 2 salariés
# 495                        NaN                   10 à 19 salariés
# 766                        NaN                     6 à 9 salariés
# 797                        NaN                    1 ou 2 salariés
#
#      fields.trancheeffectifsunitelegaletriable  fields.siretsiegeunitelegale  \
# 216                                        NaN                83405071800016
# 351                                        1.0                81065441800013
# 495                                       11.0                32765711000018
# 766                                        3.0                34088665400011
# 797                                        1.0                78467027500022
#
#        fields.siret fields.etablissementsiege fields.adresseetablissement  \
# 216  83405071800016                       oui        2 Avenue PAUL DOUMER
# 351  81065441800013                       oui  15 Avenue PRESIDENT WILSON
# 495  32765711000018                       oui      71 Avenue HENRI MARTIN
# 766  34088665400011                       oui       34 Avenue DE NEW YORK
# 797  78467027500022                       oui              27 Rue DECAMPS
#
#                      fields.sectionunitelegale  \
# 216               Autres activités de services
# 351  Arts, spectacles et activités récréatives
# 495  Arts, spectacles et activités récréatives
# 766               Autres activités de services
# 797               Autres activités de services
#
#      fields.codepostaletablissement fields.caractereemployeurunitelegale  \
# 216                         75116.0                                  Non
# 351                         75116.0                                  Oui
# 495                         75116.0                                  Oui
# 766                         75116.0                                  Oui
# 797                         75116.0                                  Oui
#
#     fields.datecreationunitelegale fields.datecreationetablissement  \
# 216                     2017-10-11                       2017-10-11
# 351                     2007-05-15                       2007-05-15
# 495                     1983-01-01                       1983-01-01
# 766                     1987-01-01                       1987-01-01
# 797                     1900-01-01                       1900-01-01
#
#             fields.denominationunitelegale geometry.type geometry.coordinates
# 216                    ASSOCIATION MANASSE           NaN                  NaN
# 351     ASSOCIATION QI GONG EE TONG FRANCE           NaN                  NaN
# 495                   CERCLE FEMININ PARIS           NaN                  NaN
# 766    AMERICAN CENTER FOR ART AND CULTURE           NaN                  NaN
# 797  AUMONERIE CATHOLIQUE JANSON-DELACROIX           NaN                  NaN

# %%
# Are they all located in the XVIe arrondissement?
SIRENE.loc[SIRENE['fields.geolocetablissement'].isna(),'fields.codepostaletablissement'].value_counts().head()
# Out:
# 75116.0    113
# 75004.0      4
# 91080.0      2
# 75015.0      2
# 76620.0      2
# Name: fields.codepostaletablissement, dtype: int64

# %%
# Almost all of them: probably the geolocalisation was not able to deal with 75116 as 'code postal' instead of 75016.
# We will try to get the geolocation based on the address (switching 75116 to 75016).

# Subsetting
subset = SIRENE.loc[SIRENE['fields.geolocetablissement'].isna()].copy()
subset['fields.codepostaletablissement'] = np.where(subset['fields.codepostaletablissement'] == 75116, '75016', subset['fields.codepostaletablissement'].astype(int))

# Geocoding
geolocator = Nominatim(user_agent="ParisSubsidies")

for i in subset.index:
    d = {'street':subset.loc[i,'fields.adresseetablissement'], 'postalcode': subset.loc[i,'fields.codepostaletablissement'], 'country':'FRANCE'}
    p = geolocator.geocode(d)
    try:
        subset.loc[i,'fields.geolocetablissement'] = '[' + str(p.longitude) + ',' + str(p.latitude) + ']'
    except:
        pass

# %%
subset.loc[subset['fields.geolocetablissement'].isna(), ['fields.adresseetablissement', 'fields.codepostaletablissement', 'fields.denominationunitelegale']]
# Out:
#              fields.adresseetablissement fields.codepostaletablissement  \
# 2768                  DEPARTEMENTALE 128                          91190
# 3297         8 Place LES COPAINS D ABORD                          91080
# 3480   1 Place MAL DE LATTRE DE TASSIGNY                          75016
# 4570     Place MAL DE LATTRE DE TASSIGNY                          75016
# 5055   1 Place MAL DE LATTRE DE TASSIGNY                          75016
# 5156     55 Rue DU 329E RGT D'INFANTERIE                          76620
# 5876       7 Place M RENAUD -JL BARRAULT                          75015
# 6587                    PARC D'ACTIVITES                          84120
# 6954            5 Avenue LA GRANDE ARMEE                          75016
# 7114     55 Rue DU 329E RGT D'INFANTERIE                          76620
# 7714     Place MAL DE LATTRE DE TASSIGNY                          75016
# 7768             17 Rue DU 26EME DRAGONS                          21000
# 7968             ZAC DES CORNILLONS NORD                          93200
# 9092            5 Rue JOSEPH ET M HACKIN                          75016
# 9625     Place MAL DE LATTRE DE TASSIGNY                          75016
# 10360    Place MAL DE LATTRE DE TASSIGNY                          75016
#
#                           fields.denominationunitelegale
# 2768                             SYSTEM@TIC PARIS REGION
# 3297                                LES PASSEURS D'ONDES
# 3480                            ASSOCIATION SPI DAUPHINE
# 4570                                OREILLE DE  DAUPHINE
# 5055                                 THEATRE A  DAUPHINE
# 5156                              ASSOCIATION LA BAZOOKA
# 5876                                LES DONNEURS DE VOIX
# 6587                                               ACIDD
# 6954   CENTRE DE RECHERCHE INTERDISCIPLINAIRE EN JURI...
# 7114                                      COMPAGNIE AKTE
# 7714   ETUDIANTS DU MASTER MANAGEMENT DES ORGANISATIO...
# 7768                                      26000 COUVERTS
# 7968                             JUSTICE DEUXIEME CHANCE
# 9092                                                FERT
# 9625                            FLEUR DE BITUME-DAUPHINE
# 10360                                         GO TO TOGO

# %%
# Manual input for remaining NaNs
subset.loc[2768, 'fields.geolocetablissement'] = '[48.6572354,2.18586]'
subset.loc[3297, 'fields.geolocetablissement'] = '[48.6287341,2.4156858]'
subset.loc[3480, 'fields.geolocetablissement'] = '[48.8710273,2.271914]'
subset.loc[4570, 'fields.geolocetablissement'] = '[48.8710273,2.271914]'
subset.loc[5055, 'fields.geolocetablissement'] = '[48.8710273,2.271914]'
subset.loc[5156, 'fields.geolocetablissement'] = '[49.5039949,0.122207]'
subset.loc[5876, 'fields.geolocetablissement'] = '[48.8383529,2.2972237]'
subset.loc[6587, 'fields.geolocetablissement'] = '[43.7033551,5.5627938]'
subset.loc[6954, 'fields.geolocetablissement'] = '[48.8742464,2.2901752]'
subset.loc[7114, 'fields.geolocetablissement'] = '[49.5039949,0.122207]'
subset.loc[7714, 'fields.geolocetablissement'] = '[48.8710273,2.271914]'
subset.loc[7768, 'fields.geolocetablissement'] = '[47.3322116,5.0458991]'
subset.loc[7968, 'fields.geolocetablissement'] = '[48.9255848,2.3621314]'
subset.loc[9092, 'fields.geolocetablissement'] = '[48.8421348,2.3316201]'
subset.loc[9625, 'fields.geolocetablissement'] = '[48.8710273,2.271914]'
subset.loc[10360, 'fields.geolocetablissement'] = '[48.8710273,2.271914]'

# %%
# Load data into SIRENE
for i in subset.index:
    SIRENE.loc[i, 'fields.geolocetablissement'] = subset.loc[i,'fields.geolocetablissement']

# %% [markdown]
# ### fields.trancheeffectifsunitelegale & fields.trancheeffectifsunitelegaletriable
# NaNs are 'Etablissement non employeur' with triable = -1

# %%
SIRENE['fields.trancheeffectifsunitelegale'].fillna('Etablissement non employeur', inplace = True)
SIRENE['fields.trancheeffectifsunitelegaletriable'].fillna(-1, inplace = True)

# %% [markdown]
# ### fields.adresseetablissement
# We keep it for visualisation purposes (hover labels).
#
# We just need to fill the NaNs.

# %%
SIRENE.loc[SIRENE['fields.adresseetablissement'].isna()]
# Out:
#       fields.libellecommuneetablissement fields.categorieentreprise  \
# 1267                          LES PILLES                        PME
# 4846                 COEUVRES-ET-VALSERY                        PME
# 6327                           LOUHOSSOA                        PME
# 7612             FLEURY-DEVANT-DOUAUMONT              Non productif
# 10836                            PRASLAY                        PME
# 11123                       SOURCE-SEINE              Non productif
#
#       fields.geolocetablissement fields.trancheeffectifsunitelegale  \
# 1267       [44.379526, 5.188954]        Etablissement non employeur
# 4846       [49.335993, 3.151804]                    1 ou 2 salariés
# 6327      [43.317797, -1.355818]                   10 à 19 salariés
# 7612        [49.193794, 5.43252]        Etablissement non employeur
# 10836       [47.74088, 5.105861]                    1 ou 2 salariés
# 11123      [47.490598, 4.686979]        Etablissement non employeur
#
#        fields.trancheeffectifsunitelegaletriable  \
# 1267                                        -1.0
# 4846                                         1.0
# 6327                                        11.0
# 7612                                        -1.0
# 10836                                        1.0
# 11123                                       -1.0
#
#        fields.siretsiegeunitelegale    fields.siret fields.etablissementsiege  \
# 1267                 41763712100019  41763712100019                       oui
# 4846                 38750560500023  38750560500023                       oui
# 6327                 41103434100049  41103434100049                       oui
# 7612                 78339244200019  78339244200019                       oui
# 10836                47957806400012  47957806400012                       oui
# 11123                50097582600016  50097582600016                       oui
#
#       fields.adresseetablissement                  fields.sectionunitelegale  \
# 1267                          NaN               Autres activités de services
# 4846                          NaN  Arts, spectacles et activités récréatives
# 6327                          NaN  Arts, spectacles et activités récréatives
# 7612                          NaN  Arts, spectacles et activités récréatives
# 10836                         NaN  Arts, spectacles et activités récréatives
# 11123                         NaN               Autres activités de services
#
#       fields.codepostaletablissement fields.caractereemployeurunitelegale  \
# 1267                         26110.0                                  Non
# 4846                          2600.0                                  Non
# 6327                         64250.0                                  Oui
# 7612                         55100.0                                  Non
# 10836                        52160.0                                  Oui
# 11123                        21690.0                                  Non
#
#       fields.datecreationunitelegale fields.datecreationetablissement  \
# 1267                      1997-11-01                       1997-11-01
# 4846                      1991-06-25                       2005-05-31
# 6327                      1996-02-26                       2008-09-20
# 7612                      1900-01-01                       1900-01-01
# 10836                     2004-10-18                       2004-10-18
# 11123                     2007-11-15                       2007-11-15
#
#             fields.denominationunitelegale
# 1267              ASSOCIATION AFRICULTURES
# 4846                   LA LANTERNE MAGIQUE
# 6327              LE PETIT THEATRE DE PAIN
# 7612          COMITE DU MEMORIAL DE VERDUN
# 10836                         LES DECISIFS
# 11123  ASSOCIATION DES SOURCES DE LA SEINE

# %%
SIRENE.loc[1267, 'fields.adresseetablissement'] = 'Le Village'
SIRENE.loc[4846, 'fields.adresseetablissement'] = '28 Rue Gabrielle d\'Estrées'
SIRENE.loc[6327, 'fields.adresseetablissement'] = 'Le Bourg'
SIRENE.loc[7612, 'fields.adresseetablissement'] = '1 Av. Corps Européen'
SIRENE.loc[10836, 'fields.adresseetablissement'] = '2 Rue des Chassaignes'
SIRENE.loc[11123, 'fields.adresseetablissement'] = '22 Rue de Saint-Germain'

# %%
# all in upper case
SIRENE['fields.adresseetablissement'] = SIRENE['fields.adresseetablissement'].str.upper()

# %% [markdown]
# ### fields.sectionunitelegale
# Not very informative, we have better information in the subsidies file, we can drop it.

# %%
SIRENE.drop('fields.sectionunitelegale', axis = 1, inplace = True)

# %% [markdown]
# ### fields.denominationunitelegale
# Fill the NaNs

# %%
SIRENE.loc[SIRENE['fields.denominationunitelegale'].isna()]
# Out:
#      fields.libellecommuneetablissement fields.categorieentreprise  \
# 1523                           PARIS 20                        PME
# 2498                           PARIS 16              Non productif
# 5732                           PARIS 18                        PME
# 5886                           PARIS 14                        PME
#
#      fields.geolocetablissement fields.trancheeffectifsunitelegale  \
# 1523      [48.863613, 2.405414]        Etablissement non employeur
# 2498      [48.837568, 2.259573]        Etablissement non employeur
# 5732      [48.890392, 2.345489]        Etablissement non employeur
# 5886      [48.819309, 2.343683]        Etablissement non employeur
#
#       fields.trancheeffectifsunitelegaletriable  fields.siretsiegeunitelegale  \
# 1523                                       -1.0                50980367200013
# 2498                                       -1.0                51265462500015
# 5732                                       -1.0                82122548900011
# 5886                                       -1.0                52837795500026
#
#         fields.siret fields.etablissementsiege fields.adresseetablissement  \
# 1523  50980367200013                       oui           4  VLA DES LYANES
# 2498  51265462500015                       oui                10 Rue GUDIN
# 5732  82122548900011                       oui                59 Rue RAMEY
# 5886  52837795500018                       non         1 Boulevard JOURDAN
#
#      fields.codepostaletablissement fields.caractereemployeurunitelegale  \
# 1523                        75020.0                                  Non
# 2498                        75016.0                                  Non
# 5732                        75018.0                                  Non
# 5886                        75014.0                                  Non
#
#      fields.datecreationunitelegale fields.datecreationetablissement  \
# 1523                     2009-01-09                       2009-01-09
# 2498                     2009-06-02                       2009-06-02
# 5732                     2016-07-01                       2016-07-01
# 5886                     2009-03-16                       2009-03-16
#
#      fields.denominationunitelegale
# 1523                            NaN
# 2498                            NaN
# 5732                            NaN
# 5886                            NaN

# %%
SIRENE.loc[1523, 'fields.denominationunitelegale'] = 'ALESSANDRA LE DU'
SIRENE.loc[2498, 'fields.denominationunitelegale'] = 'NADIA BARBE'
SIRENE.loc[5732, 'fields.denominationunitelegale'] = 'VERONIQUE RIEFFEL'
SIRENE.loc[5886, 'fields.denominationunitelegale'] = 'AHMED LAHLOU'

# %% [markdown]
# ### geometry.type and geometry.coordinates
# All points and duplicated information with fields.geolocetablissement so we can drop them

# %%
SIRENE.drop(['geometry.type', 'geometry.coordinates'], axis = 1, inplace = True)

# %% [markdown]
# ### Columns name
# We can remove all the 'fields.'

# %%
SIRENE.columns = SIRENE.columns.str.replace('fields.', '', regex=False)

# %%
SIRENE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11108 entries, 0 to 11156
# Data columns (total 14 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   libellecommuneetablissement         11108 non-null  object
#  1   categorieentreprise                 11108 non-null  object
#  2   geolocetablissement                 11108 non-null  object
#  3   trancheeffectifsunitelegale         11108 non-null  object
#  4   trancheeffectifsunitelegaletriable  11108 non-null  float64
#  5   siretsiegeunitelegale               11108 non-null  int64
#  6   siret                               11108 non-null  int64
#  7   etablissementsiege                  11108 non-null  object
#  8   adresseetablissement                11108 non-null  object
#  9   codepostaletablissement             11108 non-null  object
#  10  caractereemployeurunitelegale       11108 non-null  object
#  11  datecreationunitelegale             11108 non-null  object
#  12  datecreationetablissement           11108 non-null  object
#  13  denominationunitelegale             11108 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.3+ MB

# %%
SIRENE.head()
# Out:
#   libellecommuneetablissement categorieentreprise    geolocetablissement  \
# 0                    PARIS 12                 PME   [48.843084, 2.38305]
# 1                    PARIS 20                 PME  [48.854959, 2.397993]
# 2                    PARIS 18       Non productif  [48.886052, 2.360784]
# 3                    PARIS 15                 PME  [48.831203, 2.296779]
# 4                    PARIS 17                 PME  [48.895408, 2.321683]
#
#    trancheeffectifsunitelegale  trancheeffectifsunitelegaletriable  \
# 0               3 à 5 salariés                                 2.0
# 1               6 à 9 salariés                                 3.0
# 2  Etablissement non employeur                                -1.0
# 3              1 ou 2 salariés                                 1.0
# 4               3 à 5 salariés                                 2.0
#
#    siretsiegeunitelegale           siret etablissementsiege  \
# 0         31939212200036  31939212200036                oui
# 1         78480996400033  78480996400033                oui
# 2         48880307300011  48880307300011                oui
# 3         40206283000045  40206283000045                oui
# 4         79258420300014  79258420300014                oui
#
#      adresseetablissement codepostaletablissement  \
# 0     78 RUE DU CHAROLAIS                 75012.0
# 1  77 RUE ALEXANDRE DUMAS                 75020.0
# 2            19 RUE PAJOL                 75018.0
# 3       47 RUE DE DANTZIG                 75015.0
# 4          64 RUE POUCHET                 75017.0
#
#   caractereemployeurunitelegale datecreationunitelegale  \
# 0                           Oui              1980-06-04
# 1                           Oui              1900-01-01
# 2                           Non              2005-12-15
# 3                           Oui              1995-01-28
# 4                           Oui              2011-09-05
#
#   datecreationetablissement                   denominationunitelegale
# 0                1994-04-01  CENTRE THEATRE DE L'OPPRIME AUGUSTO BOAL
# 1                2000-02-26             EDUCAT POPUL CHARONNE REUNION
# 2                2005-12-15                                    CANOPY
# 3                2013-02-02                             DROITS DEVANT
# 4                2011-09-05        ASSOCIAITON MAISON DES VOLONTAIRES

# %% [markdown]
# ## SAVE

# %% [markdown]
# ### Profile report after cleaning

# %%
profile = ProfileReport(SIRENE.reset_index(drop=True), title="SIRENE Profiling Report - After Cleaning")
profile.to_file("ProfileReports/ParisSubsidies_SIRENE_af.html")
# Out:
# Summarize dataset: 100%|██████████| 36/36 [00:02<00:00, 12.40it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:01<00:00,  1.01s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  3.45it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 251.90it/s]

# %% [markdown]
# ### CSV

# %%
SIRENE.to_csv('../00_DataFiles/02_Cleaned/ParisSubsidies_SIRENE.csv', index = False)
